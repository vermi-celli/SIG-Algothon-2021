# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jupyter_nbextensions_configurator
# Out:
# ...
#      |████████████████████████████████| 479 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 9.5 MB 2.1 MB/s
# ...
#      |████████████████████████████████| 259 kB 1.0 MB/s
# ...
#      |████████████████████████████████| 551 kB 857 kB/s
# ...
#      |████████████████████████████████| 56 kB 2.1 MB/s
# ...
#      |████████████████████████████████| 178 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 133 kB 923 kB/s
# ...
#      |████████████████████████████████| 65 kB 1.4 MB/s
# ...
#      |████████████████████████████████| 177 kB 2.6 MB/s
# ...
#      |████████████████████████████████| 112 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 283 kB 1.3 MB/s
# ...
#      |████████████████████████████████| 84 kB 1.6 MB/s
# ...
#      |████████████████████████████████| 82 kB 876 kB/s
# ...
#      |████████████████████████████████| 56 kB 2.7 MB/s
# ...
#      |████████████████████████████████| 68 kB 1.5 MB/s
# ...
#      |████████████████████████████████| 53 kB 1.2 MB/s
# ...
#      |████████████████████████████████| 40 kB 2.5 MB/s
# ...

# %%
pip install jupyter_contrib_nbextensions
# Out:
# ...
#      |████████████████████████████████| 20.9 MB 2.5 MB/s
# ...
#      |████████████████████████████████| 4.6 MB 3.2 MB/s
# ...
#      |████████████████████████████████| 861 kB 3.4 MB/s
# ...
# Using legacy 'setup.py install' for jupyter-latex-envs, since package 'wheel' is not installed.
# ...
#     Running setup.py install for jupyter-latex-envs ... done
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge jupyter_contrib_nbextensions
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/qy/hyy9g2sx2r19b3pv71c_4dym0000gn/T/ipykernel_1823/733307293.py in <module>
# ----> 1 get_ipython().run_line_magic('conda', 'install -c conda-forge jupyter_contrib_nbextensions')
#
# ~/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2346                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2347             with self.builtin_trap:
# -> 2348                 result = fn(*args, **kwargs)
#    2349             return result
#    2350
#
# ~/Library/Python/3.9/lib/python/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
# ...

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
X = np.random.normal(0, 1, 100)

# %%
X = np.random.normal(0, 1, 100)
X2 = np.random.normal(0, 1, 100)

plt.plot(X);
plt.plot(X2);
plt.xlabel("Time")
plt.ylabel("Returns")
plt.legend(["X", "X2"])

# %%
np.mean(X)
# Out:
# 0.1315368080409159

# %%
np.var(X)
# Out:
# 0.8820762315706198

# %%
np.std(X)
# Out:
# 0.9391891351429805

# %%
get_pricing?
# Out:
# Object `get_pricing` not found.

# %%
len(Progress)
# Out:
# 250

# %%
days = []
f = open('/Users/ivykim/Downloads/algothon21-main/prices250.txt')
    #days = f.readlines()

listlist = []
for line in f:
     Day = line.strip()
     Price_Day = Day.split()
     listlist.append(Price_Day)

Progress = []
Stock = 0 #choose the instrument
for list in listlist:
    Price = list[Stock]
    Progress.append(Price)

Stockmove = []
for str in Progress:
    Price = float(str)
    Stockmove.append(Price)

Daylist = range(1, 251)
fig, ax = plt.subplots(figsize=(10,6))
ax.plot(Daylist,
        Stockmove)

#count=0
#for day in days: 
    #count += 1
    #print(f'day {count}: {day}')

# %%
listlist[1]
# Out:
# ['18.22',
#  '7.35',
#  '18.01',
#  '0.57',
#  '2.41',
#  '8.38',
#  '17.58',
#  '22.15',
#  '16.62',
#  '3.35',
#  '33.98',
#  '1.11',
#  '7.40',
#  '21.07',
#  '29.97',
#  '26.46',
#  '30.67',
#  '23.00',
#  '5.03',
#  '41.80',
#  '15.08',
#  '1.84',
#  '4.62',
#  '10.60',
#  '5.62',
#  '47.32',
#  '13.74',
#  '16.89',
#  '12.01',
#  '25.66',
#  '26.64',
#  '19.29',
#  '14.37',
#  '5.71',
#  '31.49',
#  '8.31',
#  '17.57',
#  '12.94',
#  '23.32',
#  '22.42',
#  '7.80',
#  '44.27',
#  '22.38',
#  '79.39',
#  '39.24',
#  '58.12',
#  '75.96',
#  '30.95',
#  '34.40',
#  '47.21',
#  '15.33',
#  '9.91',
#  '18.57',
#  '12.90',
#  '18.91',
#  '9.37',
#  '15.96',
#  '16.29',
#  '24.57',
#  '0.49',
#  '15.95',
#  '22.36',
#  '11.48',
#  '18.18',
#  '18.94',
#  '21.90',
#  '15.00',
#  '16.47',
#  '10.01',
#  '26.73',
#  '16.08',
#  '30.77',
#  '29.11',
#  '25.23',
#  '9.44',
#  '13.02',
#  '19.97',
#  '17.84',
#  '24.00',
#  '6.99',
#  '19.06',
#  '29.36',
#  '20.38',
#  '19.62',
#  '3.75',
# ...

# %%
f = open('/Users/ivykim/Downloads/algothon21-main/prices250.txt', 'r')
for line in f:
    Price = [el[0] for el in line]
    print (Price)
# Out:
# ', ' ', ' ', '1', '9', '.', '4', '2', ' ', ' ', ' ', ' ', ' ', ' ', '7', '.', '4', '2', ' ', ' ', ' ', ' ', ' ', '1', '8', '.', '9', '9', ' ', ' ', ' ', ' ', ' ', ' ', '0', '.', '4', '6', ' ', ' ', ' ', ' ', ' ', ' ', '2', '.', '3', '4', ' ', ' ', ' ', ' ', ' ', ' ', '8', '.', '0', '7', ' ', ' ', ' ', ' ', ' ', '1', '6', '.', '1', '7', ' ', ' ', ' ', ' ', ' ', '2', '1', '.', '2', '3', ' ', ' ', ' ', ' ', ' ', '1', '9', '.', '8', '5', ' ', ' ', ' ', ' ', ' ', ' ', '2', '.', '5', '6', ' ', ' ', ' ', ' ', ' ', '3', '3', '.', '7', '6', ' ', ' ', ' ', ' ', ' ', ' ', '1', '.', '0', '5', ' ', ' ', ' ', ' ', ' ', ' ', '7', '.', '8', '5', ' ', ' ', ' ', ' ', ' ', '1', '5', '.', '2', '3', ' ', ' ', ' ', ' ', ' ', '2', '7', '.', '4', '9', ' ', ' ', ' ', ' ', ' ', '2', '9', '.', '8', '3', ' ', ' ', ' ', ' ', ' ', '3', '0', '.', '3', '1', ' ', ' ', ' ', ' ', ' ', '2', '4', '.', '4', '2', ' ', ' ', ' ', ' ', ' ', ' ', '5', '.', '5', '5', ' ', ' ', ' ', ' ', ' ', '4', '1', '.', '7', '0', ' ', ' ', 
# ...

# %%
Price = []
with open('/Users/ivykim/Downloads/algothon21-main/prices250.txt') as f:
    for line in f:
        Price.append(line.split(None, 250)[0])
Num_days = 250
Count = 0
while Count!=capacity:
    line = Price[Count]
    for word in line.split():
        print(word)
        Count = Count + 1
# Out:
# 18.25
# 18.22
# 18.28
# 18.07
# 18.20
# 18.15
# 18.24
# 18.39
# 18.34
# 18.41
# 18.36
# 18.43
# 18.62
# 18.74
# 18.35
# 18.42
# 18.32
# 18.16
# 17.89
# 18.12
# 18.15
# 18.12
# 18.08
# 18.46
# 18.31
# 18.36
# 18.36
# 18.19
# 18.10
# 18.21
# 18.26
# 18.42
# 18.61
# 18.69
# 18.65
# 18.58
# 18.43
# 18.22
# 18.14
# 18.51
# 18.63
# 18.56
# 18.52
# 18.28
# 18.33
# 18.38
# 18.45
# 18.33
# 18.57
# 18.40
# 18.45
# 18.43
# 18.30
# 18.36
# 18.34
# 18.40
# 18.39
# 18.37
# 18.23
# 18.17
# 18.29
# 18.26
# 18.02
# 18.04
# 18.02
# 18.15
# 18.09
# 18.13
# 18.16
# 18.15
# 18.12
# 18.07
# 18.08
# 18.15
# 18.07
# 18.32
# 18.35
# 18.37
# 18.37
# 18.71
# 18.59
# 18.56
# 18.40
# 18.65
# 18.67
# 18.64
# 18.73
# 18.80
# 19.02
# 18.94
# 18.80
# 18.59
# 18.59
# 18.59
# 18.62
# 18.64
# 18.86
# 19.08
# 19.21
# 19.62
# 19.71
# 19.61
# 19.53
# 19.66
# 19.71
# 19.78
# 19.83
# 19.81
# 19.87
# 19.85
# 20.04
# 19.97
# 20.12
# 19.85
# 19.76
# 19.92
# 19.98
# 19.97
# 19.90
# 19.87
# 19.88
# 19.90
# 19.93
# 19.90
# 19.72
# ...

# %%
line.split?
# Out:
# Signature: line.split(sep=None, maxsplit=-1)
# Docstring:
# Return a list of the words in the string, using sep as the delimiter string.
#
# sep
#   The delimiter according which to split the string.
#   None (the default value) means split according to any whitespace,
#   and discard empty strings from the result.
# maxsplit
#   Maximum number of splits to do.
#   -1 (the default value) means no limit.
# Type:      builtin_function_or_method
